# %%
import os
import sys

mvae_dir = os.path.split(os.getcwd())[0]
if mvae_dir not in sys.path:
    sys.path.append(mvae_dir)
    
import torch
import numpy as np
import torch.optim as optim

import lib.dataloaders.synthetic_loader as dataloader
import lib.models.vae.euclidean_vae as model
import lib.trainer as trainer
import lib.utils as utils

from configs.clelia_configs import all_configs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       5 if mvae_dir not in sys.path:
#       6     sys.path.append(mvae_dir)
# ----> 8 import torch
#       9 import numpy as np
#      10 import torch.optim as optim
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/__init__.py:367
#     365     if USE_GLOBAL_DEPS:
#     366         _load_global_deps()
# --> 367     from torch._C import *  # noqa: F403
#     370 class SymInt:
#     371     """
#     372     Like an int (including magic methods), but redirects all operations on the
#     373     wrapped node. This is used in particular to symbolically record operations
#     374     in the symbolic shape workflow.
#     375     """
#
# ImportError: /home/timtom/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/../../../libtorch_python.so: undefined symbol: _ZN5torch3jit5fuser6onednn9fuseGraphERSt10shared_ptrINS0_5GraphEE

# %%
torch.manual_seed(42)
np.random.seed(42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 torch.manual_seed(42)
#       2 np.random.seed(42)
#
# NameError: name 'torch' is not defined

# %%
for name, config in all_configs.items():
    print("----------------------------------------------------------------")
    print(f"Running {name} with latent_dim={config.experiment}")
    print("----------------------------------------------------------------")
    data_loader = dataloader.load_synthetic_ds(config)
    train_loader, test_loader = data_loader
    vae_model = model.EuclideanVAE(config)
    optimizer = optim.Adam(vae_model.parameters(), lr=config.learning_rate)
    history = trainer.MVAETrainer(vae_model, data_loader, optimizer, config).train()
    utils.show_training_history(history)
    utils.plot_data_latents_recon(config, vae_model, train_loader)
    utils.plot_empiric_curvature(config=config, model=vae_model, data_loader=train_loader)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 for name, config in all_configs.items():
#       2     print("----------------------------------------------------------------")
#       3     print(f"Running {name} with latent_dim={config.experiment}")
#
# NameError: name 'all_configs' is not defined
