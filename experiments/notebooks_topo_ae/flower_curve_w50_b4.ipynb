# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments

# %%
base_config = {
    # Experiment
    "experiment": "ae_flower_curve_w50_b64",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s1_synthetic",
    "batch_size": 64,
    "rotation": "random",
    "translation": "random",
    "n_times": 10000,
    "embedding_dim": 10,
    "radius": 2,
    "noise_var": 0.0001,
    "n_wiggles": 5,
    "geodesic_distortion_amp": 0.1,
    "geodesic_distortion_func": "wiggles",  # Accepted values "wiggles" or "bump"

    # Model
    'model_type': 'EuclideanAE',
    "data_dim": 10,
    'latent_dim': 2,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [50, 50, 50],
    'decoder_widths': [50, 50, 50],
    'activation': "softplus",

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 100,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_true_curv": True,
    "compute_learned_curv": False,
    "compute_rec_curv": True,
    "quadric_dim": 1,
    "n_plot_points": 3000,
    "n_points_emp_curv": 3000,
    "n_points_pullback_curv": 3000, 
    "k": 130,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}

param_grid = {
    "wiggling_dim": [4] * 11,
    "embedding_dim": [10] * 11,
    "alpha": [1] * 2 + [1, 1, 0] * 3,
    "gamma": [0] * 2 + [1, 100, 1] * 3,
    "geodesic_distortion_amp": [0.3] * 11,
    "dim_topo_loss": [0] + [1] + [0] * 3 + [1] * 3 + [2] * 3,
    'encoder_widths': [[50, 50, 50]] * 11,
    'decoder_widths': [[50, 50, 50]] * 11,
}


all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_ae_flower_curve_w50_b64.
# Description: wiggling_dim=4, embedding_dim=10, alpha=1, gamma=0, geodesic_distortion_amp=0.3, dim_topo_loss=0, encoder_widths=[50, 50, 50], decoder_widths=[50, 50, 50]
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:81, in run_experiment(name, all_configs)
#      79     model = ae_model.EuclideanAE(config)
#      80     optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
# ---> 81     history = trainer.AETrainer(model, data_loader, optimizer, config).train()
#      82 elif config.model_type == "ParamAE":
#      83     model = param_model.ParamAE(config)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/ae_trainer.py:28, in AETrainer.train(self)
#      25     print(f"Training the {self.model.posterior_type} AE model.")
#      27 for epoch in range(self.num_epochs):
# ---> 28     train_loss, train_recon_loss, train_topo_loss = self.train_one_epoch(epoch, self.verbose)
#      29     test_loss, test_recon_loss, test_topo_loss = self.test_one_epoch()
#      31     self.history['train_loss'].append(train_loss)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/ae_trainer.py:59, in AETrainer.train_one_epoch(self, epoch, verbose)
#      57 x = x.to(self.device)
#      58 self.optimizer.zero_grad()
# ---> 59 angles, z, x_recon = self.model(x)
#      61 loss, recon_loss, topo_loss = topo_ae_loss(self.config, x, z, x_recon)
#      62 loss.backward()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/models/ae/euclidean_ae.py:48, in EuclideanAE.forward(self, x)
#      47 def forward(self, x):
# ---> 48     angles = self.encode(x)
#      49     z = angles  # Identity embedding, to align with spherical and toroidal ae
#      50     x_recon = self.decode(z)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/models/ae/euclidean_ae.py:36, in EuclideanAE.encode(self, x)
#      34 h = x
#      35 for layer in self.encoder_linears:
# ---> 36     h = self.activation(layer(h))
#      37 s = self.fc_final_encoder(h)
#      38 return s
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (64x10 and 100x50)
