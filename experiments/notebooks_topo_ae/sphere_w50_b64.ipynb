# %%
# %pwd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments

# %%
base_config = {
    # Experiment
    "experiment": "ae_sphere_w50_b64",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "sphere_high_dim",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "deformation_amp": 10,
    "geodesic_distortion_amp": 10,
    "n_times": 8000, 
    "radius": 2.0,
    "embedding_dim": 10,
    "noise_var": 0.0005,
    "enclosing_sphere": False,

    # Model
    'model_type': 'EuclideanAE',
    'data_dim': 10,
    'latent_dim': 3,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [50, 50, 50],
    'decoder_widths': [50, 50, 50],

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 100,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 2,
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "compute_rec_curv": False,
    "n_plot_points": 2500,
    "n_points_emp_curv": 8000,  # number of points to compute the empirical curvature
    "n_points_pullback_curv": 8000,  # number of points to compute the pullback (true/learned). Should be 1000-2000.
    "k": 300,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1, 2]
}

param_grid = {
    "alpha": [1] * 3 + [1, 1, 1, 0] * 3,
    "gamma": [0] * 3 + [1, 100, 1000, 1] * 3,
    "dim_topo_loss": [0,1,2] + [0] * 4 + [1] * 4 + [2] * 4,
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_ae_sphere_w20_b64.
# Description: alpha=1, gamma=0, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# Execution time exp00_ae_sphere_w20_b64: 81.3367 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_ae_sphere_w20_b64.
# Description: alpha=1, gamma=0, dim_topo_loss=1
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:81, in run_experiment(name, all_configs)
#      79     model = ae_model.EuclideanAE(config)
#      80     optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
# ---> 81     history = trainer.AETrainer(model, data_loader, optimizer, config).train()
#      82 elif config.model_type == "ParamAE":
#      83     model = param_model.ParamAE(config)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/ae_trainer.py:28, in AETrainer.train(self)
#      25     print(f"Training the {self.model.posterior_type} AE model.")
#      27 for epoch in range(self.num_epochs):
# ---> 28     train_loss, train_recon_loss, train_topo_loss = self.train_one_epoch(epoch, self.verbose)
#      29     test_loss, test_recon_loss, test_topo_loss = self.test_one_epoch()
#      31     self.history['train_loss'].append(train_loss)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/ae_trainer.py:63, in AETrainer.train_one_epoch(self, epoch, verbose)
#      61 loss, recon_loss, topo_loss = topo_ae_loss(self.config, x, z, x_recon)
#      62 loss.backward()
# ---> 63 self.optimizer.step()
#      65 train_loss += loss.item()
#      66 train_recon_loss += recon_loss.item()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/optimizer.py:485, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     480         else:
#     481             raise RuntimeError(
#     482                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     483             )
# --> 485 out = func(*args, **kwargs)
#     486 self._optimizer_step_code()
#     488 # call optimizer step post hooks
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/optimizer.py:79, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      77     torch.set_grad_enabled(self.defaults["differentiable"])
#      78     torch._dynamo.graph_break()
# ---> 79     ret = func(self, *args, **kwargs)
#      80 finally:
#      81     torch._dynamo.graph_break()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/adam.py:236, in Adam.step(self, closure)
#     233     state_steps: list[Tensor] = []
#     234     beta1, beta2 = group["betas"]
# --> 236     has_complex = self._init_group(
#     237         group,
#     238         params_with_grad,
#     239         grads,
#     240         exp_avgs,
#     241         exp_avg_sqs,
#     242         max_exp_avg_sqs,
#     243         state_steps,
#     244     )
#     246     adam(
#     247         params_with_grad,
#     248         grads,
#    (...)
#     267         decoupled_weight_decay=group["decoupled_weight_decay"],
#     268     )
#     270 return loss
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/adam.py:158, in Adam._init_group(self, group, params_with_grad, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps)
#     153     raise RuntimeError(
#     154         "Adam does not support sparse gradients, please consider SparseAdam instead"
#     155     )
#     156 grads.append(p.grad)
# --> 158 state = self.state[p]
#     159 # Lazy state initialization
#     160 if len(state) == 0:
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/_tensor.py:1202, in Tensor.__hash__(self)
#    1197 def __hash__(self):
#    1198     # Do NOT handle __torch_function__ here as user's default
#    1199     # implementation that handle most functions will most likely do it wrong.
#    1200     # It can be easily overridden by defining this method on the user
#    1201     # subclass if needed.
# -> 1202     return id(self)
#
# KeyboardInterrupt:
