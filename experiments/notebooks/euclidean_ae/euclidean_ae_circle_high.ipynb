# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments
# Out:
# INFO: NumExpr defaulting to 8 threads.

# %%
base_config = {
    # Experiment
    "experiment": "e_ae_circle_high",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s1_high",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "n_points": 10000,
    "embedding_dim": 10,
    "radius": 2,
    "noise_var": 0.0001,
    "deformation_amp": 0.3,

    # Model
    'model_type': 'EuclideanAE',
    "data_dim": 10,
    'latent_dim': 2,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [100,100,100],
    'decoder_widths': [100,100,100],
    'activation': "softplus",

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 100,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,  # Compute topological loss
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_quadric_curv_inputs": True,
    "compute_quadric_curv_latents": True,
    "compute_quadric_curv_recons": False,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "n_plot_points": 3000,
    "n_points_emp_curv": 3000,
    "n_points_pullback_curv": 3000, 
    "k": 80,
    "smoothing": False,

    # Persistent homology
    "compute_persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}

param_grid = {
    "alpha": [1] + [1, 1, 0] * 3,
    "gamma": [0] + [1, 100, 1] * 3,
    "dim_topo_loss": [0] + [0] * 3 + [1] * 3 + [2] * 3,
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_e_ae_circle_high.
# Description: alpha=1, gamma=0, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# Estimating 1D curvature: 100%|██████████| 3000/3000 [00:02<00:00, 1201.20it/s]
# Estimating 1D curvature: 100%|██████████| 3000/3000 [00:02<00:00, 1328.81it/s]
# {'quadric_inputs_vs_latents': {'mse': 2.7873067170942663, 'smape': 69.4536541508061}}
# Execution time exp00_e_ae_circle_high: 100.6231 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_e_ae_circle_high.
# Description: alpha=1, gamma=1, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/dipl_code/mvae/experiments/scripts/run_experiments.py:58, in run_experiment(all_configs)
#      56     model = ae_model.EuclideanAE(config)
#      57     optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
# ---> 58     history = trainer.AETrainer(model, data_loader, optimizer, config).train()
#      59 elif config.model_type == "SphericalAE":
#      60     model = spherical_model.SphericalAE(config)
#
# File ~/dipl_code/mvae/lib/trainer/ae_trainer.py:74, in AETrainer.train(self)
#      70     print(f"Training the {self.model.type} AE model.")
#      72 for epoch in range(self.num_epochs):
#      73     # Train on one epoch and compute metrics
# ---> 74     train_loss, train_recon_loss, train_topo_loss = self.train_one_epoch(epoch, self.verbose)
#      76     # Evaluate on test set
#      77     test_loss, test_recon_loss, test_topo_loss = self.test_one_epoch()
#
# File ~/dipl_code/mvae/lib/trainer/ae_trainer.py:122, in AETrainer.train_one_epoch(self, epoch, verbose)
#     119 self.optimizer.zero_grad()
#     121 # Forward pass
# --> 122 angles, z, x_recon = self.model(x)
#     124 # Compute AE loss and components
#     125 loss, recon_loss, topo_loss = topo_ae_loss(self.config, x, z, x_recon)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dipl_code/mvae/lib/models/ae/euclidean_ae.py:111, in EuclideanAE.forward(self, x)
#     109 z0 = self.encode(x)
#     110 z = z0  # Identity embedding, to align with spherical or toroidal AEs
# --> 111 x_recon = self.decode(z)
#     112 return z0, z, x_recon
#
# File ~/dipl_code/mvae/lib/models/ae/euclidean_ae.py:90, in EuclideanAE.decode(self, z)
#      88 h = z
#      89 for layer in self.decoder_linears:
# ---> 90     h = self.activation(layer(h))
#      91 h = self.fc_x_recon(h)
#      92 return h
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
