# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments
# Out:
# INFO: NumExpr defaulting to 8 threads.

# %%
base_config = {
    # Experiment
    "experiment": "e_vae_sphere_high",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s2_high",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "deformation_amp": 0.6,
    "n_points": 8000,
    "radius": 2.0,
    "embedding_dim": 10,
    "noise_var": 0.0005,
    "enclosing_sphere": False,

    # Model
    'model_type': 'EuclideanVAE',
    'data_dim': 10,
    'latent_dim': 3,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [100, 100, 100],
    'decoder_widths': [100, 100, 100],
    'activation': 'softplus',

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 100,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 2,
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 1.0,   # Weight for KL-divergence loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_quadric_curv_inputs": True,
    "compute_quadric_curv_latents": True,
    "compute_quadric_curv_recons": False,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "n_plot_points": 2500,
    "n_points_emp_curv": 8000,  # number of points to compute the empirical curvature
    "n_points_pullback_curv": 3000,  # number of points to compute the pullback (true/learned). Should be 1000-2000.
    "k": 330,
    "smoothing": False,

    # Persistent homology
    "compute_persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1, 2]
}

param_grid = {
    'beta': [0.0,0.08,1.0] * 7 ,
    'gamma': [0.0] * 3 + ([1.0] * 3 + [100.0] * 3) * 3,
    'dim_topo_loss': [0] * 9 + [1] * 6 + [2] * 6,
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_e_vae_sphere_high.
# Description: beta=0.0, gamma=0.0, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# {'quadric_inputs_vs_latents': {'mse': 0.4665077994274694, 'smape': 49.182428726355255}}
# Execution time exp00_e_vae_sphere_high: 24.8584 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_e_vae_sphere_high.
# Description: beta=0.08, gamma=0.0, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/dipl_code/mvae/experiments/scripts/run_experiments.py:80, in run_experiment(name, all_configs)
#      78     model = ae_model.EuclideanAE(config)
#      79     optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
# ---> 80     history = trainer.AETrainer(model, data_loader, optimizer, config).train()
#      81 elif config.model_type == "SphericalAE":
#      82     model = spherical_model.SphericalAE(config)
#
# File ~/dipl_code/mvae/lib/trainer/ae_trainer.py:74, in AETrainer.train(self)
#      70     print(f"Training the {self.model.type} AE model.")
#      72 for epoch in range(self.num_epochs):
#      73     # Train on one epoch and compute metrics
# ---> 74     train_loss, train_recon_loss, train_topo_loss = self.train_one_epoch(epoch, self.verbose)
#      76     # Evaluate on test set
#      77     test_loss, test_recon_loss, test_topo_loss = self.test_one_epoch()
#
# File ~/dipl_code/mvae/lib/trainer/ae_trainer.py:129, in AETrainer.train_one_epoch(self, epoch, verbose)
#     127 # Backpropagation
#     128 loss.backward()
# --> 129 self.optimizer.step()
#     131 # Accumulate batch losses
#     132 train_loss += loss.item()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/optimizer.py:485, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     480         else:
#     481             raise RuntimeError(
#     482                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     483             )
# --> 485 out = func(*args, **kwargs)
#     486 self._optimizer_step_code()
#     488 # call optimizer step post hooks
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/optimizer.py:79, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      77     torch.set_grad_enabled(self.defaults["differentiable"])
#      78     torch._dynamo.graph_break()
# ---> 79     ret = func(self, *args, **kwargs)
#      80 finally:
#      81     torch._dynamo.graph_break()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/adam.py:246, in Adam.step(self, closure)
#     234     beta1, beta2 = group["betas"]
#     236     has_complex = self._init_group(
#     237         group,
#     238         params_with_grad,
#    (...)
#     243         state_steps,
#     244     )
# --> 246     adam(
#     247         params_with_grad,
#     248         grads,
#     249         exp_avgs,
#     250         exp_avg_sqs,
#     251         max_exp_avg_sqs,
#     252         state_steps,
#     253         amsgrad=group["amsgrad"],
#     254         has_complex=has_complex,
#     255         beta1=beta1,
#     256         beta2=beta2,
#     257         lr=group["lr"],
#     258         weight_decay=group["weight_decay"],
#     259         eps=group["eps"],
#     260         maximize=group["maximize"],
#     261         foreach=group["foreach"],
#     262         capturable=group["capturable"],
#     263         differentiable=group["differentiable"],
#     264         fused=group["fused"],
#     265         grad_scale=getattr(self, "grad_scale", None),
#     266         found_inf=getattr(self, "found_inf", None),
#     267         decoupled_weight_decay=group["decoupled_weight_decay"],
#     268     )
#     270 return loss
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/optimizer.py:147, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     145     return disabled_func(*args, **kwargs)
#     146 else:
# --> 147     return func(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/adam.py:933, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     930 else:
#     931     func = _single_tensor_adam
# --> 933 func(
#     934     params,
#     935     grads,
#     936     exp_avgs,
#     937     exp_avg_sqs,
#     938     max_exp_avg_sqs,
#     939     state_steps,
#     940     amsgrad=amsgrad,
#     941     has_complex=has_complex,
#     942     beta1=beta1,
#     943     beta2=beta2,
#     944     lr=lr,
#     945     weight_decay=weight_decay,
#     946     eps=eps,
#     947     maximize=maximize,
#     948     capturable=capturable,
#     949     differentiable=differentiable,
#     950     grad_scale=grad_scale,
#     951     found_inf=found_inf,
#     952     decoupled_weight_decay=decoupled_weight_decay,
#     953 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/optim/adam.py:439, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     436     device_beta1 = beta1
#     438 # Decay the first and second moment running average coefficient
# --> 439 exp_avg.lerp_(grad, 1 - device_beta1)
#     441 # Nested if is necessary to bypass jitscript rules
#     442 if differentiable and isinstance(beta2, Tensor):
#
# KeyboardInterrupt:
