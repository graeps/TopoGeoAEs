# %%
# %pwd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments

# %%
base_config = {
    # Experiment
    "experiment": "e_vae_circle_low",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s1_low",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "n_points": 10000,
    "embedding_dim": 10,
    "radius": 2,
    "noise_var": 0.0001,
    "n_wiggles": 5,
    "deformation_amp": 0.3,
    "deformation_type": "wiggles",  # Accepted values "wiggles" or "bump"

    # Model
    'model_type': 'EuclideanVAE',
    "data_dim": 10,
    'latent_dim': 2,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [100,100,100],
    'decoder_widths': [100,100,100],
    'activation': "softplus",

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 2,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 1.0,   # Weight for KL-divergence loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_quadric_curv_inputs": True,
    "compute_quadric_curv_latents": True,
    "compute_quadric_curv_recons": False,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "n_plot_points": 3000,
    "n_points_emp_curv": 3000,
    "n_points_pullback_curv": 3000, 
    "k": 130,
    "smoothing": False,

    # Persistent homology
    "compute_persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}

param_grid = {
    'beta': [0.0,0.08,1.0] * 4 ,
    'gamma': [0.0] * 3 + ([1.0] * 3) * 3,
    'dim_topo_loss': [0] * 6 + [1] * 3 + [2] * 3,
}



all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_e_vae_circle_low.
# Description: beta=0.0, gamma=0.0, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# Estimating 1D curvature: 100%|██████████| 3000/3000 [00:02<00:00, 1316.49it/s]
# Estimating 1D curvature: 100%|██████████| 3000/3000 [00:02<00:00, 1476.10it/s]
# {'quadric_inputs_vs_latents': {'mse': 0.613499587295225, 'smape': 23.397298696427736}}
# Execution time exp00_e_vae_circle_low: 10.7289 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_e_vae_circle_low.
# Description: beta=0.08, gamma=0.0, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/dipl_code/mvae/experiments/scripts/run_experiments.py:93, in run_experiment(name, all_configs)
#      90     raise NotImplementedError
#      92 visual.training_history.show_training_history(config, history)
# ---> 93 visual.plot_data_latents_recon(config, model, train_loader)
#      95 if config.compute_persistent_homology:
#      96     visual.plot_persistence(config=config, model=model, data_loader=train_loader)
#
# File ~/dipl_code/mvae/lib/visualization/data_latent_plots.py:25, in plot_data_latents_recon(config, model, data_loader)
#      12 def plot_data_latents_recon(config, model, data_loader):
#      13     """
#      14     Generates and visualizes comparison plots for input data, latent representations, and reconstructed data.
#      15     The function creates three subplots: original dataset, latent space, and reconstruction.
#    (...)
#      23         data_loader (Any): The data loader providing input data and labels for visualization.
#      24     """
# ---> 25     recons, latents, inputs, labels = get_vectors(config, model, data_loader, config.n_plot_points)
#      26     if torch.isnan(latents).any():
#      27         print("NaNs detected in the dataset!")
#
# File ~/dipl_code/mvae/lib/utils/vectors.py:46, in get_vectors(config, model, data_loader, n_samples, save_dir)
#      44     z, x_recon, _ = model(x)
#      45 elif config.model_type in {"EuclideanAE", "ParamAE", "SphericalAE", "ToroidalAE"}:
# ---> 46     angles, z, x_recon = model(x)
#      47 else:
#      48     raise NotImplementedError
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/dipl_code/mvae/lib/models/ae/euclidean_ae.py:109, in EuclideanAE.forward(self, x)
#      94 def forward(self, x):
#      95     """
#      96     Perform a full forward pass through the autoencoder.
#      97
#    (...)
#     107               (shape ``[batch_size, data_dim]``).
#     108     """
# --> 109     z0 = self.encode(x)
#     110     z = z0  # Identity embedding, to align with spherical or toroidal AEs
#     111     x_recon = self.decode(z)
#
# File ~/dipl_code/mvae/lib/models/ae/euclidean_ae.py:74, in EuclideanAE.encode(self, x)
#      72 h = x
#      73 for layer in self.encoder_linears:
# ---> 74     h = self.activation(layer(h))
#      75 s = self.fc_final_encoder(h)
#      76 return s
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/linear.py:125, in Linear.forward(self, input)
#     124 def forward(self, input: Tensor) -> Tensor:
# --> 125     return F.linear(input, self.weight, self.bias)
#
# KeyboardInterrupt:
