# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments
# Out:
# INFO: NumExpr defaulting to 8 threads.

# %%
base_config = {
    # Experiment
    "experiment": "flower_curve_AE",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s1_synthetic",
    "batch_size": 64,
    "rotation": "random",
    "translation": "random",
    "n_times": 2500,
    "embedding_dim": 10,
    "radius": 2,
    "noise_var": 0.0001,
    "n_wiggles": 5,
    "geodesic_distortion_amp": 0.3,
    "geodesic_distortion_func": "wiggles",  # Accepted values "wiggles" or "bump"

    # Model
    'model_type': 'EuclideanAE',
    "data_dim": 10,
    'latent_dim': 2,
    'manifold_dim': 1,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [400, 400, 400,1,400,400,400],
    'decoder_widths': [200,200,200],
    'activation': "softplus",

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 200,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_emp_curv": False,
    "compute_true_curv": True,
    "compute_learned_curv": True,
    "compute_rec_curv": True,
    "quadric_dim": 1,
    "n_plot_points": 1000,
    "n_points_emp_curv": 1000,
    "n_points_pullback_curv": 1000, 
    "k": 110,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}

param_grid = {
    "alpha": [1,1],
    "gamma": [0,1],
    "dim_topo_loss": [0,1],
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_flower_curve_AE.
# Description: alpha=1, gamma=0, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# InvalidConfigError                        Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:112, in run_experiment(name, all_configs)
#     110     utils.plot_curvature_persistence(config=config, model=model, data_loader=train_loader)
#     111 elif config.plot_curvatures:
# --> 112     utils.plot_all_curvatures(config=config, model=model, data_loader=train_loader)
#     114 if config.logging:
#     115     generate_experiment_report(config)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/visualization.py:897, in plot_all_curvatures(config, model, data_loader)
#     895 def plot_all_curvatures(config, model, data_loader):
#     896     recons, latents, inputs, labels = get_vectors(config, model, data_loader, config.n_points_emp_curv)
# --> 897     _plot_all_curvatures_from_vectors(config=config, model=model, recons=recons, latents=latents, inputs=inputs,
#     898                                       labels=labels)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/visualization.py:834, in _plot_all_curvatures_from_vectors(config, model, recons, latents, inputs, labels)
#     833 def _plot_all_curvatures_from_vectors(config, model, recons, latents, inputs, labels):
# --> 834     points_sub, curvatures_sub, curvatures_emp_full = compute_all_curvatures(config, model, recons, latents, inputs,
#     835                                                                              labels)
#     836     points = (inputs, latents, recons)
#     837     inputs_sub, latents_sub, recons_sub = points_sub
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/curvature.py:664, in compute_all_curvatures(config, model, recons, latents, inputs, labels, save_dir)
#     662     curv_true = np.zeros(n_points)
#     663 if config.compute_learned_curv:
# --> 664     _, _, _, curv_learned = compute_curvature_learned(config=config, model=model, latent_vectors=latents_sub,
#     665                                                       labels=labels_sub, n_grid_points=len(labels_sub))
#     666 else:
#     667     curv_learned = np.zeros(n_points)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/curvature.py:405, in compute_curvature_learned(config, model, latent_vectors, labels, n_grid_points)
#     402     z_grid = get_z_grid(config=config, n_grid_points=n_grid_points)
#     403     #z_grid = shift_z_grid(z_grid, latent_vectors[0], config)
#     404 else:
# --> 405     raise InvalidConfigError(f"Unknown model type: {config.model_type}")
#     406 immersion = get_learned_immersion(model=model, config=config)
#     407 if config.dataset_name in {"s1_synthetic", "interlocking_rings_synthetic", "scrunchy", "clelia_curve", "8_curve",
#     408                            "flower_scrunchy", "scrunchy_dim_n"}:
#
# InvalidConfigError: Unknown model type: EuclideanAE
