# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments

# %%
base_config = {
    # Experiment
    "experiment": "ae_nested_sphere_w50_b64_relu",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "nested_spheres_high_dim",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "deformation_amp": 10,
    "n_times": 8000,  # per sphere
    "major_radius": 10.0,
    "mid_radius": 5.0,
    "minor_radius": 2.0,
    "embedding_dim": 10,
    "noise_var": 0.001,
    "enclosing_sphere": False,

    # Model
    'model_type': 'EuclideanAE',
    'data_dim': 10,
    'latent_dim': 3,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [50, 50, 50],
    'decoder_widths': [50, 50, 50],
    'activation': 'relu',

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 20,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 2,
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "compute_rec_curv": False,
    "n_plot_points": 2000,
    "n_points_emp_curv": 20000,  # number of points to compute the empirical curvature
    "n_points_pullback_curv": 1500,  # number of points to compute the pullback (true/learned). Should be 1000-2000.
    "k": 300,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1, 2]
}

param_grid = {
    "alpha": [1] * 3 + [1, 1, 1, 0] * 3,
    "gamma": [0] * 3 + [1, 100, 1000, 1] * 3,
    "dim_topo_loss": [0,1,2] + [0] * 4 + [1] * 4 + [2] * 4,
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_ae_nested_sphere_w50_b64_relu.
# Description: alpha=1, gamma=0, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# Execution time exp00_ae_nested_sphere_w50_b64_relu: 144.8511 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_ae_nested_sphere_w50_b64_relu.
# Description: alpha=1, gamma=0, dim_topo_loss=1
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:103, in run_experiment(name, all_configs)
#     101     utils.plot_curvature_persistence(config=config, model=model, data_loader=train_loader)
#     102 elif config.plot_curvatures:
# --> 103     utils.plot_all_curvatures(config=config, model=model, data_loader=train_loader)
#     105 if config.logging:
#     106     generate_experiment_report(config)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/visualization.py:890, in plot_all_curvatures(config, model, data_loader)
#     888 def plot_all_curvatures(config, model, data_loader):
#     889     recons, latents, inputs, labels = get_vectors(config, model, data_loader, config.n_points_emp_curv)
# --> 890     _plot_all_curvatures_from_vectors(config=config, model=model, recons=recons, latents=latents, inputs=inputs,
#     891                                       labels=labels)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/visualization.py:827, in _plot_all_curvatures_from_vectors(config, model, recons, latents, inputs, labels)
#     826 def _plot_all_curvatures_from_vectors(config, model, recons, latents, inputs, labels):
# --> 827     points_sub, curvatures_sub, curvatures_emp_full = compute_all_curvatures(config, model, recons, latents, inputs,
#     828                                                                              labels)
#     829     points = (inputs, latents, recons)
#     830     inputs_sub, latents_sub, recons_sub = points_sub
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/curvature.py:561, in compute_all_curvatures(config, model, recons, latents, inputs, labels)
#     559 def compute_all_curvatures(config, model, recons, latents, inputs, labels):
#     560     # Compute empirical curvatures on full data
# --> 561     curv_in, curv_lat, curv_rec, labels = compute_empirical_curvature(config=config, labels=labels, inputs=inputs,
#     562                                                                       latents=latents, recons=recons, k=config.k
#     563                                                                       )
#     565     # Compute pullback curvature on (ordered) subset of points to reduce computation time
#     566     n_total = len(labels)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/curvature.py:492, in compute_empirical_curvature(config, labels, inputs, latents, recons, k)
#     490 else:
#     491     curv_in_sub = estimate_curvature_2d_quadric(inputs_sub, k)
# --> 492     curv_lat_sub = estimate_curvature_2d_quadric(latents_sub, k)
#     493     curv_rec_sub = estimate_curvature_2d_quadric(recons_sub, k)
#     495 curv_in.append(curv_in_sub)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/curvature.py:544, in estimate_curvature_2d_quadric(points, k)
#     542 centroid = neighbors.mean(axis=0)
#     543 centered = neighbors - centroid
# --> 544 pca = PCA(n_components=3).fit(centered)
#     545 normal = pca.components_[-1]
#     546 tangent = pca.components_[:2]
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/sklearn/base.py:1382, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1377 partial_fit_and_fitted = (
#    1378     fit_method.__name__ == "partial_fit" and _is_fitted(estimator)
#    1379 )
#    1381 if not global_skip_validation and not partial_fit_and_fitted:
# -> 1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
#    1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/sklearn/base.py:438, in BaseEstimator._validate_params(self)
#     428 def _validate_params(self):
#     429     """Validate types and values of constructor parameters
#     430
#     431     The expected type and values must be defined in the `_parameter_constraints`
#    (...)
#     434     accepted constraints.
#     435     """
#     436     validate_parameter_constraints(
#     437         self._parameter_constraints,
# --> 438         self.get_params(deep=False),
#     439         caller_name=self.__class__.__name__,
#     440     )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/sklearn/base.py:247, in BaseEstimator.get_params(self, deep)
#     232 """
#     233 Get parameters for this estimator.
#     234
#    (...)
#     244     Parameter names mapped to their values.
#     245 """
#     246 out = dict()
# --> 247 for key in self._get_param_names():
#     248     value = getattr(self, key)
#     249     if deep and hasattr(value, "get_params") and not isinstance(value, type):
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/sklearn/base.py:229, in BaseEstimator._get_param_names(cls)
#     221         raise RuntimeError(
#     222             "scikit-learn estimators should always "
#     223             "specify their parameters in the signature"
#    (...)
#     226             " follow this convention." % (cls, init_signature)
#     227         )
#     228 # Extract and sort argument names excluding 'self'
# --> 229 return sorted([p.name for p in parameters])
#
# KeyboardInterrupt:
