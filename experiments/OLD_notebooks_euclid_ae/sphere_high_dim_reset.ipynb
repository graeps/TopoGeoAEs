# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments
# Out:
# INFO: NumExpr defaulting to 8 threads.

# %%
base_config = {
    # Experiment
    "experiment": "sphere_high_dim_reset",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "sphere",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "deformation_amp": 0.6,
    "n_times": 8000, 
    "radius": 2.0,
    "embedding_dim": 10,
    "noise_var": 0.0005,
    "enclosing_sphere": False,

    # Model
    'model_type': 'EuclideanAE',
    'data_dim': 10,
    'latent_dim': 3,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [100, 100, 100],
    'decoder_widths': [100, 100, 100],
    'activation': 'softplus',

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 100,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 2,
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    'compute_emp_curv': True,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "compute_rec_curv": False,
    "n_plot_points": 2500,
    "n_points_emp_curv": 8000,  # number of points to compute the empirical curvature
    "n_points_pullback_curv": 3000,  # number of points to compute the pullback (true/learned). Should be 1000-2000.
    "k": 330,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1, 2]
}

param_grid = {
    "alpha": [1, 1, 1, 1, 0],
    "gamma": [1, 1, 1,1, 1],
    "dim_topo_loss": [1,0,1,2,1],
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_sphere_high_dim_reset.
# Description: alpha=1, gamma=1, dim_topo_loss=1
# --------------------------------------------------------------------------------------
# Execution time exp00_sphere_high_dim_reset: 136.5339 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_sphere_high_dim_reset.
# Description: alpha=1, gamma=1, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# Execution time exp01_sphere_high_dim_reset: 251.1427 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp02_sphere_high_dim_reset.
# Description: alpha=1, gamma=1, dim_topo_loss=1
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:90, in run_experiment(name, all_configs)
#      88     model = ae_model.EuclideanAE(config)
#      89     optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
# ---> 90     history = trainer.AETrainer(model, data_loader, optimizer, config).train()
#      91 elif config.model_type == "ParamAE":
#      92     model = param_model.ParamAE(config)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/ae_trainer.py:28, in AETrainer.train(self)
#      25     print(f"Training the {self.model.posterior_type} AE model.")
#      27 for epoch in range(self.num_epochs):
# ---> 28     train_loss, train_recon_loss, train_topo_loss = self.train_one_epoch(epoch, self.verbose)
#      29     test_loss, test_recon_loss, test_topo_loss = self.test_one_epoch()
#      31     self.history['train_loss'].append(train_loss)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/ae_trainer.py:61, in AETrainer.train_one_epoch(self, epoch, verbose)
#      58 self.optimizer.zero_grad()
#      59 angles, z, x_recon = self.model(x)
# ---> 61 loss, recon_loss, topo_loss = topo_ae_loss(self.config, x, z, x_recon)
#      62 loss.backward()
#      63 self.optimizer.step()
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/loss_functions.py:96, in topo_ae_loss(config, x, z, x_recon)
#      94 if topo_loss:
#      95     vr = VietorisRipsComplex(dim=config.dim_topo_loss)
# ---> 96     pi_x = vr(x)
#      97     pi_z = vr(z)
#      98     topo_loss = SignatureLoss(p=2, dimensions=config.dim_topo_loss)([x, pi_x], [z, pi_z])
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch_topological/nn/vietoris_rips_complex.py:133, in VietorisRipsComplex.forward(self, x, treat_as_distances)
#      93 def forward(self, x, treat_as_distances=False):
#      94     """Implement forward pass for persistence diagram calculation.
#      95
#      96     The forward pass entails calculating persistent homology on
#    (...)
#     131         dimensions will have four components.
#     132     """
# --> 133     return batch_handler(
#     134         x,
#     135         self._forward,
#     136         treat_as_distances=treat_as_distances
#     137     )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch_topological/nn/data.py:296, in batch_handler(x, handler_fn, **kwargs)
#     294     return [handler_fn(torch.as_tensor(x_), **kwargs) for x_ in x]
#     295 else:
# --> 296     return handler_fn(torch.as_tensor(x), **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch_topological/nn/vietoris_rips_complex.py:167, in VietorisRipsComplex._forward(self, x, treat_as_distances)
#     164 else:
#     165     distances = torch.cdist(x, x, p=self.p)
# --> 167 generators = ripser_parallel(
#     168     distances.cpu().detach().numpy(),
#     169     metric='precomputed',
#     170     **self.ripser_params
#     171 )['gens']
#     173 # We always have 0D information.
#     174 persistence_information = \
#     175     self._extract_generators_and_diagrams(
#     176         distances,
#     177         generators,
#     178         dim0=True,
#     179     )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/gph/python/ripser_interface.py:625, in ripser_parallel(X, maxdim, thresh, coeff, metric, metric_params, nearest_neighbors_params, weights, weight_params, collapse_edges, n_threads, return_generators)
#     618     res = _compute_ph_vr_dense(DParam, diagonal, maxdim, thresh,
#     619                                coeff, n_threads, return_generators)
#     621 # Unwrap persistence diagrams
#     622 # Barcodes must match the inner type of C++ core filtration value.
#     623 # We call a method from the bindings that returns the barcodes as
#     624 # numpy arrays with np.float32 type
# --> 625 dgms = res.births_and_deaths_by_dim()
#     626 for dim in range(len(dgms)):
#     627     N = int(len(dgms[dim]) / 2)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/_internal.py:652, in _dtype_from_pep3118(spec)
#     648     def __bool__(self):
#     649         return bool(self.s)
# --> 652 def _dtype_from_pep3118(spec):
#     653     stream = _Stream(spec)
#     654     dtype, align = __dtype_from_pep3118(stream, is_subdtype=False)
#
# KeyboardInterrupt:
