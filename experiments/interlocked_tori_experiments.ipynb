# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
from scripts.run_experiments import run_experiment
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from scripts.run_experiments import run_experiment
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:3
#       1 import os
#       2 import sys
# ----> 3 import torch
#       4 import numpy as np
#       5 import torch.optim as optim
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/__init__.py:2126
#    2119 from torch._compile import _disable_dynamo  # usort: skip
#    2121 ################################################################################
#    2122 # Import interface functions defined in Python
#    2123 ################################################################################
#    2124
#    2125 # needs to be after the above ATen bindings so we can overwrite from Python side
# ...

# %%
run_experiment("interlocked_tori")
