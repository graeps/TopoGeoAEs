# %%
# %pwd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from scripts.run_experiments import run_experiment

# %%
run_experiment("torus")
# Out:
# ...
# Running exp00_torus.
# Description: alpha=1, gamma=0, deformation_amp=0.5, dim_topo_loss=0
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 run_experiment("torus")
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:65, in run_experiment(name, all_configs)
#      62 utils.plot_data_latents_recon(config, vae_model, train_loader)
#      64 if config.persistent_homology:
# ---> 65     utils.plot_curvature_persistence(config=config, model=vae_model, data_loader=train_loader)
#      66 else:
#      67     utils.plot_all_curvatures(config=config, model=vae_model, data_loader=train_loader)
#
# ...
