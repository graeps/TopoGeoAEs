# %%
# %pwd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from scripts.run_experiments import run_experiment

# %%
run_experiment("interlocked_tori")
# Out:
# ----------------------------------------------------------------
# Running exp00_interlocked_tori. Description: alpha=1.0, gamma=100.0, dim_topo_loss=0, deformation_amp=3, k=40
# ----------------------------------------------------------------
# ...
# Estimating 2D curvature: 100%|██████████| 1000/1000 [00:00<00:00, 1301.11it/s]
# Computing curvature from immersion  (Manifold Dim > 1): 100%|██████████| 1000/1000 [00:15<00:00, 65.67it/s]
# Computing curvature from immersion  (Manifold Dim > 1): 100%|██████████| 1000/1000 [00:11<00:00, 85.24it/s]
# ----------------------------------------------------------------
# Running exp01_interlocked_tori. Description: alpha=1.0, gamma=100.0, dim_topo_loss=0, deformation_amp=3, k=50
# ----------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 1
# ...
