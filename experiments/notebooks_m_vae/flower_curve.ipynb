# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments

# %%
base_config = {
    # Experiment
    "experiment": "vae_flower_curve",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s1_synthetic",
    "batch_size": 64,
    "rotation": "random",
    "translation": "random",
    "n_times": 10000,
    "embedding_dim": 10,
    "radius": 2,
    "noise_var": 0.0001,
    "n_wiggles": 5,
    "geodesic_distortion_amp": 0.3,
    "geodesic_distortion_func": "wiggles",  # Accepted values "wiggles" or "bump"

    # Model
    'model_type': 'VMFSphericalVAE',
    "data_dim": 10,
    'latent_dim': 2,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [20, 20, 20],
    'decoder_widths': [20, 20, 20],
    'activation': "softplus",

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 100,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.03,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_emp_curv": False,
    "compute_true_curv": True,
    "compute_learned_curv": True,
    "compute_rec_curv": False,
    "quadric_dim": 1,
    "n_plot_points": 3000,
    "n_points_emp_curv": 2000,
    "n_points_pullback_curv": 2000, 
    "k": 130,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}

param_grid = {
    "encoder_widths": [[20,20,20],[50,50,50],[100,100,100],[400,400,400]],
    "decoder_widths": [[20,20,20],[50,50,50],[100,100,100],[400,400,400]],
}


all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_vae_flower_curve.
# Description: encoder_widths=[20, 20, 20], decoder_widths=[20, 20, 20]
# --------------------------------------------------------------------------------------
# Execution time exp00_vae_flower_curve: 162.8532 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_vae_flower_curve.
# Description: encoder_widths=[50, 50, 50], decoder_widths=[50, 50, 50]
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:108, in run_experiment(name, all_configs)
#     106     utils.plot_curvature_persistence(config=config, model=model, data_loader=train_loader)
#     107 elif config.plot_curvatures:
# --> 108     utils.plot_all_curvatures(config=config, model=model, data_loader=train_loader)
#     110 if config.logging:
#     111     generate_experiment_report(config)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/visualization.py:897, in plot_all_curvatures(config, model, data_loader)
#     895 def plot_all_curvatures(config, model, data_loader):
#     896     recons, latents, inputs, labels = get_vectors(config, model, data_loader, config.n_points_emp_curv)
# --> 897     _plot_all_curvatures_from_vectors(config=config, model=model, recons=recons, latents=latents, inputs=inputs,
#     898                                       labels=labels)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/visualization.py:834, in _plot_all_curvatures_from_vectors(config, model, recons, latents, inputs, labels)
#     833 def _plot_all_curvatures_from_vectors(config, model, recons, latents, inputs, labels):
# --> 834     points_sub, curvatures_sub, curvatures_emp_full = compute_all_curvatures(config, model, recons, latents, inputs,
#     835                                                                              labels)
#     836     points = (inputs, latents, recons)
#     837     inputs_sub, latents_sub, recons_sub = points_sub
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/curvature.py:649, in compute_all_curvatures(config, model, recons, latents, inputs, labels)
#     647     curv_true = np.zeros(len(labels_sub))
#     648 if config.compute_learned_curv:
# --> 649     _, _, _, curv_learned = compute_curvature_learned(config=config, model=model, latent_vectors=latents_sub,
#     650                                                       labels=labels_sub, n_grid_points=len(labels_sub))
#     651 else:
#     652     curv_learned = np.zeros(len(labels_sub))
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/curvature.py:397, in compute_curvature_learned(config, model, latent_vectors, labels, n_grid_points)
#     395 immersion = get_learned_immersion(model, config)
#     396 manifold_dim = z_grid.shape[1] if z_grid.ndim > 1 else 1
# --> 397 curv, curv_norm = _compute_curvature(z_grid, immersion, manifold_dim, config.embedding_dim)
#     398 return z_grid, labels, curv, curv_norm
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/utils/curvature.py:372, in _compute_curvature(z_grid, immersion, dim, embedding_dim)
#     370             z = torch.tensor(z)
#     371         z = torch.unsqueeze(z, dim=0)
# --> 372         curv[i, :] = neural_manifold.metric.mean_curvature_vector(z)
#     373 else:
#     374     curv = torch.full((len(z_grid), embedding_dim), torch.nan)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/geometry/pullback_metric.py:180, in PullbackMetric.mean_curvature_vector(self, base_point)
#     161 def mean_curvature_vector(self, base_point):
#     162     r"""Compute the mean curvature vector.
#     163
#     164     The mean curvature vector is defined at base point :math:`p` by
#    (...)
#     178         Mean curvature vector.
#     179     """
# --> 180     second_fund_form = self.second_fundamental_form(base_point)
#     181     cometric = self.cometric_matrix(base_point)
#     182     return gs.einsum("...ij,...aij->...a", cometric, second_fund_form)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/geometry/pullback_metric.py:154, in PullbackMetric.second_fundamental_form(self, base_point)
#     134 def second_fundamental_form(self, base_point):
#     135     r"""Compute the second fundamental form.
#     136
#     137     In the case of an immersion f, the second fundamental form is
#    (...)
#     152         :math:`\alpha` index is first.
#     153     """
# --> 154     christoffels = self.christoffels(base_point)
#     156     jacobian = self._space.jacobian_immersion(base_point)
#     157     hessian = self._space.hessian_immersion(base_point)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/geometry/riemannian_metric.py:158, in RiemannianMetric.christoffels(self, base_point)
#     133 r"""Compute Christoffel symbols of the Levi-Civita connection.
#     134
#     135 The Koszul formula defining the Levi-Civita connection gives the
#    (...)
#     155     Christoffel symbols, where the contravariant index is first.
#     156 """
#     157 cometric_mat_at_point = self.cometric_matrix(base_point)
# --> 158 metric_derivative_at_point = self.inner_product_derivative_matrix(base_point)
#     160 term_1 = gs.einsum(
#     161     "...lk,...jli->...kij", cometric_mat_at_point, metric_derivative_at_point
#     162 )
#     163 term_2 = gs.einsum(
#     164     "...lk,...lij->...kij", cometric_mat_at_point, metric_derivative_at_point
#     165 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/geometry/pullback_metric.py:129, in PullbackMetric.inner_product_derivative_matrix(self, base_point)
#     108 r"""Compute the inner-product derivative matrix.
#     109
#     110 The derivative of the metrix matrix is given by
#    (...)
#     126     is last: :math:`mat_{ijk} = \partial_k g_{ij}`.
#     127 """
#     128 jacobian_ai = self._space.jacobian_immersion(base_point)
# --> 129 hessian_aij = self._space.hessian_immersion(base_point)
#     130 return gs.einsum("...aki,...aj->...ijk", hessian_aij, jacobian_ai) + gs.einsum(
#     131     "...akj,...ai->...ijk", hessian_aij, jacobian_ai
#     132 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/geometry/base.py:822, in ImmersedSet.hessian_immersion(self, base_point)
#     809 def hessian_immersion(self, base_point):
#     810     """Compute the Hessian of the immersion.
#     811
#     812     Parameters
#    (...)
#     820         Hessian at the base point
#     821     """
# --> 822     return gs.autodiff.hessian_vec(
#     823         self.immersion, func_out_ndim=self.embedding_space.dim
#     824     )(base_point)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/_backend/pytorch/autodiff.py:254, in hessian_vec.<locals>._hessian(point)
#     252 def _hessian(point):
#     253     if point.ndim == point_ndim:
# --> 254         return hessian_func(point)
#     255     return _torch.stack(
#     256         [hessian_func(one_point) for one_point in point],
#     257         axis=0,
#     258     )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/_backend/pytorch/autodiff.py:218, in hessian.<locals>._hessian_vector_valued(point)
#     214 def scalar_func(point, a):
#     215     return func(point)[a]
#     217 return _torch.stack(
# --> 218     [
#     219         hessian(functools.partial(scalar_func, a=a))(point)
#     220         for a in range(func_out_ndim)
#     221     ]
#     222 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/_backend/pytorch/autodiff.py:219, in <listcomp>(.0)
#     214 def scalar_func(point, a):
#     215     return func(point)[a]
#     217 return _torch.stack(
#     218     [
# --> 219         hessian(functools.partial(scalar_func, a=a))(point)
#     220         for a in range(func_out_ndim)
#     221     ]
#     222 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/geomstats/_backend/pytorch/autodiff.py:211, in hessian.<locals>._hessian(point)
#     210 def _hessian(point):
# --> 211     return _torch_hessian(func=lambda x: func(x), inputs=point, strict=True)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/functional.py:958, in hessian(func, inputs, create_graph, strict, vectorize, outer_jacobian_strategy)
#     955     _check_requires_grad(jac, "jacobian", strict=strict)
#     956     return jac
# --> 958 res = jacobian(
#     959     jac_func,
#     960     inputs,
#     961     create_graph=create_graph,
#     962     strict=strict,
#     963     vectorize=vectorize,
#     964     strategy=outer_jacobian_strategy,
#     965 )
#     966 return _tuple_postprocess(res, (is_inputs_tuple, is_inputs_tuple))
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/functional.py:676, in jacobian(func, inputs, create_graph, strict, vectorize, strategy)
#     673 is_inputs_tuple, inputs = _as_tuple(inputs, "inputs", "jacobian")
#     674 inputs = _grad_preprocess(inputs, create_graph=create_graph, need_graph=True)
# --> 676 outputs = func(*inputs)
#     677 is_outputs_tuple, outputs = _as_tuple(
#     678     outputs, "outputs of the user-provided function", "jacobian"
#     679 )
#     680 _check_requires_grad(outputs, "outputs", strict=strict)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/functional.py:954, in hessian.<locals>.jac_func(*inp)
#     950 if outer_jacobian_strategy == "forward-mode":
#     951     # _grad_preprocess requires create_graph=True and input to require_grad
#     952     # or else the input will be detached
#     953     inp = tuple(t.requires_grad_(True) for t in inp)
# --> 954 jac = jacobian(ensure_single_output_function, inp, create_graph=True)
#     955 _check_requires_grad(jac, "jacobian", strict=strict)
#     956 return jac
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/functional.py:788, in jacobian(func, inputs, create_graph, strict, vectorize, strategy)
#     786 jac_i: tuple[list[torch.Tensor]] = tuple([] for _ in range(len(inputs)))  # type: ignore[assignment]
#     787 for j in range(out.nelement()):
# --> 788     vj = _autograd_grad(
#     789         (out.reshape(-1)[j],),
#     790         inputs,
#     791         retain_graph=True,
#     792         create_graph=create_graph,
#     793     )
#     795     for el_idx, (jac_i_el, vj_el, inp_el) in enumerate(
#     796         zip(jac_i, vj, inputs)
#     797     ):
#     798         if vj_el is not None:
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/functional.py:194, in _autograd_grad(outputs, inputs, grad_outputs, create_graph, retain_graph, is_grads_batched)
#     192     return (None,) * len(inputs)
#     193 else:
# --> 194     return torch.autograd.grad(
#     195         new_outputs,
#     196         inputs,
#     197         new_grad_outputs,
#     198         allow_unused=True,
#     199         create_graph=create_graph,
#     200         retain_graph=retain_graph,
#     201         is_grads_batched=is_grads_batched,
#     202     )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/__init__.py:502, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched, materialize_grads)
#     498     result = _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(
#     499         grad_outputs_
#     500     )
#     501 else:
# --> 502     result = _engine_run_backward(
#     503         outputs,
#     504         grad_outputs_,
#     505         retain_graph,
#     506         create_graph,
#     507         inputs,
#     508         allow_unused,
#     509         accumulate_grad=False,
#     510     )
#     511 if materialize_grads:
#     512     if any(
#     513         result[i] is None and not is_tensor_like(inputs[i])
#     514         for i in range(len(inputs))
#     515     ):
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:
