# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments

# %%
base_config = {
    # Experiment
    "experiment": "toroidal_VAE_acosta_vmf",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "t2_synthetic",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "n_times": 2500,
    "embedding_dim": 10,
    "major_radius": 2,
    "minor_radius": 1,
    "noise_var": 0.001,
    "geodesic_distortion_amp": 0.0,

    # Model
    'model_type': 'VMFToroidalVAE',
    'latent_dim': 2,
    'manifold_dim': 2,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_width': 400,
    'encoder_depth': 3,
    'decoder_width': 200,
    'decoder_depth': 3,

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 50,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': False,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 1.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": False,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "compute_rec_curv": True,
    "quadric_dim": 1,
    "n_plot_points": 2500,
    "n_points_emp_curv": 1000,
    "n_points_pullback_curv": 1000, 
    "k": 110,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}


param_grid = {
    'num_epochs': [600],
    'noise_var': [0.0001],
    'activation': ['softplus'],
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_toroidal_VAE_acosta_vmf.
# Description: num_epochs=600, noise_var=0.0001, activation=softplus
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:78, in run_experiment(name, all_configs)
#      76     model = vmf_toroidal_vae_model.VMFToroidalVAE(config)
#      77     optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
# ---> 78     history = trainer.MVAETrainer(model, data_loader, optimizer, config).train()
#      79 elif config.model_type == "VMFSphericalVAE":
#      80     model = vmf_spherical_vae_model.VMFSphericalVAE(config)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/mvae_trainer.py:35, in MVAETrainer.train(self)
#      32     print(f"Training the {self.model.posterior_type} VAE model.")
#      34 for epoch in range(self.num_epochs):
# ---> 35     train_loss, train_recon_loss, train_kl_loss, train_topo_loss = self.train_one_epoch(epoch, self.verbose)
#      36     test_loss, test_recon_loss, test_kl_loss, test_topo_loss = self.test_one_epoch()
#      38     self.history['train_loss'].append(train_loss)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/mvae_trainer.py:69, in MVAETrainer.train_one_epoch(self, epoch, verbose)
#      67 x = x.to(self.device)
#      68 self.optimizer.zero_grad()
# ---> 69 z, x_recon, posterior_params = self.model(x)
#      70 loss, recon_loss, kl_loss, topo_loss = elbo(self.model.posterior_type, x, z, x_recon, posterior_params,
#      71                                             self.config)
#      72 loss.backward()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/models/vae/vmf_toroidal_vae.py:170, in VMFToroidalVAE.forward(self, x)
#     150 """Run VAE: Encode, sample and decode.
#     151
#     152 Parameters
#    (...)
#     165     multivariate Gaussian in latent space.
#     166 """
#     168 posterior_params = self.encode(x)
# --> 170 z = self.reparameterize(posterior_params)
#     172 x_recon = self.decode(z)
#     174 return z, x_recon, posterior_params
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/models/vae/vmf_toroidal_vae.py:124, in VMFToroidalVAE.reparameterize(self, posterior_params)
#     120 q_z_phi = VonMisesFisher(z_phi_mu, z_phi_kappa)
#     122 z_theta = q_z_theta.rsample()
# --> 124 z_phi = q_z_phi.rsample()
#     126 return self._build_torus(z_theta, z_phi)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/distributions/von_mises_fisher.py:58, in VonMisesFisher.rsample(self, shape)
#      52     shape = torch.Size()
#      53 shape = shape if isinstance(shape, torch.Size) else torch.Size([shape])
#      55 w = (
#      56     self.__sample_w3(shape=shape)
#      57     if self.__m == 3
# ---> 58     else self.__sample_w_rej(shape=shape)
#      59 )
#      61 v = (
#      62     torch.distributions.Normal(0, 1)
#      63     .sample(shape + torch.Size(self.loc.shape))
#      64     .to(self.device)
#      65     .transpose(0, -1)[1:]
#      66 ).transpose(0, -1)
#      67 v = v / v.norm(dim=-1, keepdim=True)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/distributions/von_mises_fisher.py:101, in VonMisesFisher.__sample_w_rej(self, shape)
#      98 a = (self.__m - 1 + 2 * self.scale + c) / 4
#      99 d = (4 * a * b) / (1 + b) - (self.__m - 1) * math.log(self.__m - 1)
# --> 101 self.__b, (self.__e, self.__w) = b, self.__while_loop(b, a, d, shape, k=self.k)
#     102 return self.__w
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/distributions/von_mises_fisher.py:128, in VonMisesFisher.__while_loop(self, b, a, d, shape, k, eps)
#     125 sample_shape = torch.Size([b.shape[0], k])
#     126 shape = shape + torch.Size(self.scale.shape)
# --> 128 while bool_mask.sum() != 0:
#     129     con1 = torch.tensor((self.__m - 1) / 2, dtype=torch.float64)
#     130     con2 = torch.tensor((self.__m - 1) / 2, dtype=torch.float64)
#
# KeyboardInterrupt:
