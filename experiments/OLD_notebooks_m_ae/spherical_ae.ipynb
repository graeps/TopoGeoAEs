# %%
# %pwd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from scripts.run_experiments import run_experiment
from scripts.experiment_utils import generate_experiments

# %%
base_config = {
    # Experiment
    "experiment": "spherical_AE",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s1_synthetic",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "n_times": 1500,
    "embedding_dim": 10,
    "radius": 1,
    "noise_var": 0.001,
    "n_wiggles": 0,
    "geodesic_distortion_amp": 0.0,
    "geodesic_distortion_func": "wiggles",  # Accepted values "wiggles" or "bump"

    # Model
    'model_type': 'SphericalAE',
    'latent_dim': 2,
    'manifold_dim': 1,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [50,50,50],
    'decoder_widths': [50,50,50],
    'use_angle_constraint': False,

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 50,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': False,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": False,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "compute_rec_curv": True,
    "quadric_dim": 1,
    "n_plot_points": 10000,
    "n_points_emp_curv": 1000,
    "n_points_pullback_curv": 1000, 
    "k": 110,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}

param_grid = {
    "dataset_name": (["s1_synthetic"] * 3 + ["s2_synthetic"] * 3) * 2,
    "latent_dim": ([2] * 3 + [3] * 3) * 2,
    'encoder_widths': ([[30,30,30], [50,50,50], [100,100,100]] * 2) * 2,
    'decoder_widths': ([[30,30,30], [50,50,50], [100,100,100]] * 2) * 2,
    'activation': ['softplus'] * 6 + ['relu'] * 6,
    'num_epochs': [200] * 12,
    'noise_var': ([0.0001] * 3 + [0.001] * 3) * 2,
    'n_times': ([1500] * 3 + [2500] * 3) * 2
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_spherical_AE.
# Description: dataset_name=s1_synthetic, latent_dim=2, encoder_widths=[30, 30, 30], decoder_widths=[30, 30, 30], activation=softplus, num_epochs=200, noise_var=0.0001, n_times=1500
# --------------------------------------------------------------------------------------
# Execution time exp00_spherical_AE: 18.8161 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_spherical_AE.
# Description: dataset_name=s1_synthetic, latent_dim=2, encoder_widths=[50, 50, 50], decoder_widths=[50, 50, 50], activation=softplus, num_epochs=200, noise_var=0.0001, n_times=1500
# --------------------------------------------------------------------------------------
# Execution time exp01_spherical_AE: 36.4334 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp02_spherical_AE.
# Description: dataset_name=s1_synthetic, latent_dim=2, encoder_widths=[100, 100, 100], decoder_widths=[100, 100, 100], activation=softplus, num_epochs=200, noise_var=0.0001, n_times=1500
# --------------------------------------------------------------------------------------
# Execution time exp02_spherical_AE: 57.6015 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp03_spherical_AE.
# Description: dataset_name=s2_synthetic, latent_dim=3, encoder_widths=[30, 30, 30], decoder_widths=[30, 30, 30], activation=softplus, num_epochs=200, noise_var=0.001, n_times=2500
# --------------------------------------------------------------------------------------
# Execution time exp03_spherical_AE: 84.6043 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp04_spherical_AE.
# Description: dataset_name=s2_synthetic, latent_dim=3, encoder_widths=[50, 50, 50], decoder_widths=[50, 50, 50], activation=softplus, num_epochs=200, noise_var=0.001, n_times=2500
# --------------------------------------------------------------------------------------
# Execution time exp04_spherical_AE: 112.5474 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp05_spherical_AE.
# Description: dataset_name=s2_synthetic, latent_dim=3, encoder_widths=[100, 100, 100], decoder_widths=[100, 100, 100], activation=softplus, num_epochs=200, noise_var=0.001, n_times=2500
# --------------------------------------------------------------------------------------
# Execution time exp05_spherical_AE: 146.3830 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp06_spherical_AE.
# Description: dataset_name=s1_synthetic, latent_dim=2, encoder_widths=[30, 30, 30], decoder_widths=[30, 30, 30], activation=relu, num_epochs=200, noise_var=0.0001, n_times=1500
# --------------------------------------------------------------------------------------
# Execution time exp06_spherical_AE: 163.1472 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp07_spherical_AE.
# Description: dataset_name=s1_synthetic, latent_dim=2, encoder_widths=[50, 50, 50], decoder_widths=[50, 50, 50], activation=relu, num_epochs=200, noise_var=0.0001, n_times=1500
# --------------------------------------------------------------------------------------
# Execution time exp07_spherical_AE: 181.6252 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp08_spherical_AE.
# Description: dataset_name=s1_synthetic, latent_dim=2, encoder_widths=[100, 100, 100], decoder_widths=[100, 100, 100], activation=relu, num_epochs=200, noise_var=0.0001, n_times=1500
# --------------------------------------------------------------------------------------
# Execution time exp08_spherical_AE: 200.2120 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp09_spherical_AE.
# Description: dataset_name=s2_synthetic, latent_dim=3, encoder_widths=[30, 30, 30], decoder_widths=[30, 30, 30], activation=relu, num_epochs=200, noise_var=0.001, n_times=2500
# --------------------------------------------------------------------------------------
# Execution time exp09_spherical_AE: 226.4817 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp10_spherical_AE.
# Description: dataset_name=s2_synthetic, latent_dim=3, encoder_widths=[50, 50, 50], decoder_widths=[50, 50, 50], activation=relu, num_epochs=200, noise_var=0.001, n_times=2500
# --------------------------------------------------------------------------------------
# Execution time exp10_spherical_AE: 254.7910 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp11_spherical_AE.
# Description: dataset_name=s2_synthetic, latent_dim=3, encoder_widths=[100, 100, 100], decoder_widths=[100, 100, 100], activation=relu, num_epochs=200, noise_var=0.001, n_times=2500
# --------------------------------------------------------------------------------------
# Execution time exp11_spherical_AE: 287.7200 seconds
