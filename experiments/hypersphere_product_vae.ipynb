# %% [markdown]
# # Toroidal VAE

# %%
import os
import sys
mvae_dir = os.path.split(os.getcwd())[0]
if mvae_dir not in sys.path:
    sys.path.append(mvae_dir)

# %%
# %pwd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Imports

# %%
import torch
import numpy as np
import torch.optim as optim

import lib.dataloaders as dataloaders
import lib.models as models
import lib.trainer as trainer
import lib.utils as utils
import lib.models.utils.save_load_models as modelutils

# %% [markdown]
# ### Set up and initialize data loader

# %%
# Set random seed for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# %% [markdown]
#  ### Dataloader

# %%
batch_size = 64

dataloader = dataloaders.load_fashion_mnist(batch_size)
train_loader, test_loader = dataloader

# %% [markdown]
# ### Model

# %%
data_dim = 28*28
latent_dim = 2
sftbeta = 1
device = "cpu"
encoder_width = 128
encoder_depth = 1
decoder_width = 128
decoder_depth = 1

model_config = {'data_dim': data_dim, 'latent_dim': latent_dim, 'sftbeta': sftbeta, 'device': device,
                'encoder_width': encoder_width, 'encoder_depth': encoder_depth, 'decoder_width': decoder_width,
                'decoder_depth': decoder_depth}

toroidal_model = models.ToroidalVAE(model_config)

# %% [markdown]
# ### Optimizer

# %%
learning_rate = 0.001

toroidal_optimizer = optim.Adam(toroidal_model.parameters(), lr=learning_rate)

# %% [markdown]
# ### Train and evaluate model

# %%
num_epochs = 1
log_interval = 100
device = "cpu"
recon_loss = "MSE"

trainer_config = {'num_epochs': num_epochs, 'log_interval': log_interval, 'device': device, 'recon_loss': recon_loss}

toroidal_history = trainer.MVAETrainer(toroidal_model, dataloader, toroidal_optimizer, trainer_config).train()
# Out:
# Trainer successfully initialized.
# Training the toroidalVAE model.
# Starting epoch 1/1
# Epoch [1/1], Step [100/938], Loss: 4444.0068
# Epoch [1/1], Step [200/938], Loss: 4441.0396
# Epoch [1/1], Step [300/938], Loss: 4599.0801
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[76], line 8
#       4 recon_loss = "MSE"
#       6 trainer_config = {'num_epochs': num_epochs, 'log_interval': log_interval, 'device': device, 'recon_loss': recon_loss}
# ----> 8 toroidal_history = trainer.MVAETrainer(toroidal_model, dataloader, toroidal_optimizer, trainer_config).train()
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/mvae_trainer.py:30, in MVAETrainer.train(self)
#      27 print("Training the " + f'{self.model.posterior_type}' + "VAE model.")
#      29 for epoch in range(self.num_epochs):
# ---> 30     train_loss, train_recon_loss, train_kl_loss = self.train_one_epoch(epoch)
#      31     test_loss, test_recon_loss, test_kl_loss = self.test_one_epoch()
#      33     self.history['train_loss'].append(train_loss)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/mvae_trainer.py:60, in MVAETrainer.train_one_epoch(self, epoch)
#      56 _, x_recon, posterior_params = self.model(x)
#      57 loss, recon_loss, kl_loss = elbo(self.model.posterior_type, x, x_recon, posterior_params,
#      58                                  self.model.latent_dim, self.recon_loss,
#      59                                  self.device)
# ---> 60 loss.backward()
#      62 # for name, param in self.model.named_parameters():
#      63 #     if param.grad is not None:
#      64 #         print(f"Layer: {name}, Gradient: {param.grad}")
#      65 #     else:
#      66 #         print(f"Layer: {name}, Gradient: None")
#      68 self.optimizer.step()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/_tensor.py:525, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     515 if has_torch_function_unary(self):
#     516     return handle_torch_function(
#     517         Tensor.backward,
#     518         (self,),
#    (...)
#     523         inputs=inputs,
#     524     )
# --> 525 torch.autograd.backward(
#     526     self, gradient, retain_graph, create_graph, inputs=inputs
#     527 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/__init__.py:267, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     262     retain_graph = create_graph
#     264 # The reason we repeat the same comment below is that
#     265 # some Python versions print out the first line of a multi-line function
#     266 # calls in the traceback and some print out the last line
# --> 267 _engine_run_backward(
#     268     tensors,
#     269     grad_tensors_,
#     270     retain_graph,
#     271     create_graph,
#     272     inputs,
#     273     allow_unreachable=True,
#     274     accumulate_grad=True,
#     275 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/graph.py:744, in _engine_run_backward(t_outputs, *args, **kwargs)
#     742     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     743 try:
# --> 744     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     745         t_outputs, *args, **kwargs
#     746     )  # Calls into the C++ engine to run the backward pass
#     747 finally:
#     748     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Visualization

# %%
utils.show_training_history(toroidal_history)

# %% [markdown]
# ### Save trained models

# %%
#modelutils.save_model(toroidal_model, model_config)

# %% [markdown]
# ### Load pretrained models

# %%
#model = modelutils.load_model("gaussian_1740054584")
#model = toroidal_model

# %% [markdown]
# ### Visualizing the latent space

# %%
utils.plot_test_latents_on_torus(toroidal_model, test_loader, device)

# %% [markdown]
# #### Visualize reconstructed mnist images

# %%
utils.show_recon_mnist(toroidal_model, test_loader, device)
