# %%
# %pwd
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from scripts.run_experiments import run_experiment

# %%
run_experiment("wiggling_tube")
# Out:
# ----------------------------------------------------------------
# Running exp00_wiggling_tube. Description: alpha=1, gamma=0, deformation_amp=0.3, dim_topo_loss=0
# ----------------------------------------------------------------
# Computing persistence diagrams
# Computing bottleneck distance
# Computing betti curves
# Execution time: 38.4528 seconds
# Execution time exp00_wiggling_tube: 90.4122 seconds
# ----------------------------------------------------------------
# Running exp01_wiggling_tube. Description: alpha=1, gamma=1, deformation_amp=0.3, dim_topo_loss=0
# ----------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 run_experiment("wiggling_tube")
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:57, in run_experiment(name)
# ...
