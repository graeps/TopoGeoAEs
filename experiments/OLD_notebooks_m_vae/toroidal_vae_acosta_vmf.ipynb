# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments
# Out:
# INFO: NumExpr defaulting to 8 threads.

# %%
base_config = {
    # Experiment
    "experiment": "toroidal_VAE_acosta_vmf",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "t2_synthetic",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "n_times": 2500,
    "embedding_dim": 10,
    "major_radius": 2,
    "minor_radius": 1,
    "noise_var": 0.0001,
    "geodesic_distortion_amp": 0.0,

    # Model
    'model_type': 'VMFToroidalVAE',
    'latent_dim': 2,
    'manifold_dim': 2,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_width': 400,
    'encoder_depth': 5,
    'decoder_width': 400,
    'decoder_depth': 3,

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 600,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': False,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": False,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "compute_rec_curv": True,
    "quadric_dim": 1,
    "n_plot_points": 2500,
    "n_points_emp_curv": 1000,
    "n_points_pullback_curv": 1000, 
    "k": 110,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}


param_grid = {
    'noise_var': [0.0001] * 2,
    'activation': ['softplus'] * 2,
    'beta': [0.03,0.08],
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_toroidal_VAE_acosta_vmf.
# Description: noise_var=0.0001, activation=softplus, beta=0.03
# --------------------------------------------------------------------------------------
# Execution time exp00_toroidal_VAE_acosta_vmf: 1361.4223 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_toroidal_VAE_acosta_vmf.
# Description: noise_var=0.0001, activation=softplus, beta=0.08
# --------------------------------------------------------------------------------------
# Execution time exp01_toroidal_VAE_acosta_vmf: 2428.8330 seconds

# %%
param_grid = {
    'noise_var': [0.0001] * 3,
    'activation': ['softplus'] * 3,
    'beta': [1]*3,
    'logging': [False,False,True],
    'num_epochs': [1,1,600],
}

all_configs = generate_experiments(base_config, param_grid)
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_toroidal_VAE_acosta_vmf.
# Description: noise_var=0.0001, activation=softplus, beta=1, logging=False, num_epochs=1
# --------------------------------------------------------------------------------------
# Execution time exp00_toroidal_VAE_acosta_vmf: 3.1808 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_toroidal_VAE_acosta_vmf.
# Description: noise_var=0.0001, activation=softplus, beta=1, logging=False, num_epochs=1
# --------------------------------------------------------------------------------------
# Execution time exp01_toroidal_VAE_acosta_vmf: 6.1880 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp02_toroidal_VAE_acosta_vmf.
# Description: noise_var=0.0001, activation=softplus, beta=1, logging=True, num_epochs=600
# --------------------------------------------------------------------------------------
# Execution time exp02_toroidal_VAE_acosta_vmf: 1042.6718 seconds
