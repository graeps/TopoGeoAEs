# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments
# Out:
# INFO: NumExpr defaulting to 8 threads.

# %%
base_config = {
    # Experiment
    "experiment": "VAE_spherical_acosta",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s2_synthetic",
    "batch_size": 64,
    "rotation": "random",
    "translation": None,
    "n_times": 2500,
    "embedding_dim": 10,
    "radius": 1,
    "noise_var": 0.001,
    "geodesic_distortion_amp": 0.3,

    # Model
    'model_type': 'VMToroidalVAE',
    'latent_dim': 2,
    'manifold_dim': 2,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [400,400,400,400,400,400],
    'decoder_widths': [200,200,200,200],

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 50,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': False,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.03,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_emp_curv": False,
    "compute_true_curv": True,
    "compute_learned_curv": True,
    "compute_rec_curv": False,
    "quadric_dim": 1,
    "n_plot_points": 2500,
    "n_points_emp_curv": 1000,
    "n_points_pullback_curv": 1000, 
    "k": 110,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}


param_grid = {
    'num_epochs': [600] * 2,
    'noise_var': [0.0001] * 2,
    'activation': ['softplus'] * 2,
    'beta': [0.03,0.08],
}

all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
# Out:
# ======================================================================================
# ======================================================================================
# Running exp00_VAE_spherical_acosta.
# Description: num_epochs=600, noise_var=0.0001, activation=softplus, beta=0.03
# --------------------------------------------------------------------------------------
# Execution time exp00_VAE_spherical_acosta: 909.7314 seconds
#
# ======================================================================================
# ======================================================================================
# Running exp01_VAE_spherical_acosta.
# Description: num_epochs=600, noise_var=0.0001, activation=softplus, beta=0.08
# --------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 run_experiment(all_configs=all_configs)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:78, in run_experiment(name, all_configs)
#      76     model = vm_toroidal_vae_model.VMToroidalVAE(config)
#      77     optimizer = optim.Adam(model.parameters(), lr=config.learning_rate)
# ---> 78     history = trainer.MVAETrainer(model, data_loader, optimizer, config).train()
#      79 elif config.model_type == "VMFToroidalVAE":
#      80     model = vmf_toroidal_vae_model.VMFToroidalVAE(config)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/mvae_trainer.py:35, in MVAETrainer.train(self)
#      32     print(f"Training the {self.model.posterior_type} VAE model.")
#      34 for epoch in range(self.num_epochs):
# ---> 35     train_loss, train_recon_loss, train_kl_loss, train_topo_loss = self.train_one_epoch(epoch, self.verbose)
#      36     test_loss, test_recon_loss, test_kl_loss, test_topo_loss = self.test_one_epoch()
#      38     self.history['train_loss'].append(train_loss)
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/trainer/mvae_trainer.py:72, in MVAETrainer.train_one_epoch(self, epoch, verbose)
#      69 z, x_recon, posterior_params = self.model(x)
#      70 loss, recon_loss, kl_loss, topo_loss = elbo(self.model.posterior_type, x, z, x_recon, posterior_params, labels,
#      71                                             self.config)
# ---> 72 loss.backward()
#      73 self.optimizer.step()
#      75 train_loss += loss.item()
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)
#     646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File ~/miniconda3/envs/mvae-env/lib/python3.10/site-packages/torch/autograd/graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:
