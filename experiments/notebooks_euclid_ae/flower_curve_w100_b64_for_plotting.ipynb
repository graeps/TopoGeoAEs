# %%
# %pwd
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

project_root = os.path.abspath(os.path.join(os.getcwd(), "../../"))
if project_root not in sys.path:
    sys.path.insert(0, project_root)
from experiments.scripts.run_experiments import run_experiment
from experiments.scripts.experiment_utils import generate_experiments
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       5 if project_root not in sys.path:
#       6     sys.path.insert(0, project_root)
# ----> 7 from experiments.scripts.run_experiments import run_experiment
#       8 from experiments.scripts.experiment_utils import generate_experiments
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/experiments/scripts/run_experiments.py:17
#      14 os.environ["GEOMSTATS_BACKEND"] = "pytorch"
#      15 import geomstats.backend as gs  # noqa: E402
# ---> 17 import lib.dataloaders.synthetic_loader as synthetic_loader
#      18 import lib.dataloaders.flat_torus_loader as flat_torus_loader
#      19 import lib.models.vae.euclidean_vae as e_vae_model
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/dataloaders/synthetic_loader.py:4
#       1 from torch.utils.data import TensorDataset, DataLoader, random_split
#       2 import torch
# ----> 4 from ..datasets.datasets_main import load_s1_low, load_scrunchy, \
#       5     load_interlocking_rings_synthetic, load_s2_low, load_t2_low, load_flower_scrunchy
#       7 from ..datasets.datasets_other import generate_genus3, \
#       8     load_nested_spheres, load_clelia_curve, load_8_curve, load_interlocked_tori, load_t2_high, load_wiggling_tube, \
#       9     load_nested_spheres_high_dim_bump, load_interlocked_tubes, load_s1_high, load_sphere_high_dim_bump, \
#      10     load_s2_high
#      13 def load_synthetic_ds(config):
#
# File ~/Documents/uni_math/diplomarbeit/code/mvae/lib/datasets/datasets_main.py:2
#       1 import os
# ----> 2 import panda as pd
#       4 # Set Geomstats backend before importing it
#       5 os.environ["GEOMSTATS_BACKEND"] = "pytorch"
#
# ModuleNotFoundError: No module named 'panda'

# %%
base_config = {
    # Experiment
    "experiment": "ae_flower_curve_w100_b64_for_plotting",
    "random_seed": 42,
    "logging": True,

    # Dataset
    "dataset_name": "s1_synthetic",
    "batch_size": 64,
    "rotation": "random",
    "translation": "random",
    "n_times": 10000,
    "embedding_dim": 10,
    "radius": 2,
    "noise_var": 0.0001,
    "n_wiggles": 5,
    "geodesic_distortion_amp": 0.3,
    "geodesic_distortion_func": "wiggles",  # Accepted values "wiggles" or "bump"

    # Model
    'model_type': 'EuclideanAE',
    "data_dim": 10,
    'latent_dim': 2,
    'sftbeta': 4.5,
    'device': "cpu",
    'encoder_widths': [50, 50, 50],
    'decoder_widths': [50, 50, 50],
    'activation': "softplus",

    # Optimizer
    "learning_rate": 0.001,

    # Trainer
    'verbose': False,
    'num_epochs': 100,
    'log_interval': 100,
    'recon_loss': "MSE",
    'topo_loss': True,
    'dim_topo_loss': 0,  # Max feature dimension topological loss
    'alpha': 1.0,  # Weight for reconstruction loss
    'beta': 0.0,  # Weight for KL loss
    'gamma': 0.0,  # Weight for topological loss

    # Curvature computation
    "plot_curvatures": True,
    "compute_emp_curv": True,
    "compute_true_curv": False,
    "compute_learned_curv": False,
    "compute_rec_curv": True,
    "quadric_dim": 1,
    "n_plot_points": 3000,
    "n_points_emp_curv": 3000,
    "n_points_pullback_curv": 3000, 
    "k": 130,
    "smoothing": False,

    # Persistent homology
    "persistent_homology": False,
    "n_points_pers_hom": 1000,
    "scale": False,
    "homology_dimensions": [0, 1]
}

param_grid = {
    "alpha": [1, 1, 0],
    "gamma": [0, 1, 1],
    "dim_topo_loss": [0,0,0],
    'encoder_widths': [[100, 100, 100]] * 3,
    'decoder_widths': [[100, 100, 100]] * 3,
}


all_configs = generate_experiments(base_config, param_grid)

# %%
run_experiment(all_configs=all_configs)
